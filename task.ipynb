# %% [markdown]
# <a href="https://colab.research.google.com/github/Polamreddykrishnareddy/ReluConsultancy-/blob/main/task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv("Amazon.csv")
data
# Out:
#      Unnamed: 0       id        Asin country
# 0             0        1        1015      de
# 1             1  2424796        1015      fr
# 2             2        2  000004458X      de
# 3             3  2424797  000004458X      fr
# 4             4        3     1002198      de
# ..          ...      ...         ...     ...
# 995         995  2425286     4484924      fr
# 996         996      449     4485742      de
# 997         997  2425287     4485742      fr
# 998         998      450     4486072      de
# 999         999  2425288     4486072      fr
#
# [1000 rows x 4 columns]

# %%
country=list(data["country"])
country[:5]
# Out:
# ['de', 'fr', 'de', 'fr', 'de']

# %%
Asin =list(data["Asin"])
Asin[0:5]
# Out:
# ['1015', '1015', '000004458X', '000004458X', '1002198']

# %%
import bs4
url=[]
for i in country:
  for j in Asin:
    URL= "https://www.amazon.{}/dp/{}".format(i,j)
    url.append(URL)

b =list(dict.fromkeys(url))
print(b,end=" ")
print(len(b))
# Out:
# ['https://www.amazon.de/dp/1015', 'https://www.amazon.de/dp/000004458X', 'https://www.amazon.de/dp/1002198', 'https://www.amazon.de/dp/1002791', 'https://www.amazon.de/dp/1002864', 'https://www.amazon.de/dp/1003704', 'https://www.amazon.de/dp/1003763', 'https://www.amazon.de/dp/1004271', 'https://www.amazon.de/dp/000101742X', 'https://www.amazon.de/dp/1017519', 'https://www.amazon.de/dp/000102163X', 'https://www.amazon.de/dp/1022369', 'https://www.amazon.de/dp/1022857', 'https://www.amazon.de/dp/1032666', 'https://www.amazon.de/dp/1034677', 'https://www.amazon.de/dp/1034936', 'https://www.amazon.de/dp/1034944', 'https://www.amazon.de/dp/1035002', 'https://www.amazon.de/dp/1035029', 'https://www.amazon.de/dp/1035053', 'https://www.amazon.de/dp/1035339', 'https://www.amazon.de/dp/1036866', 'https://www.amazon.de/dp/1037137', 'https://www.amazon.de/dp/1037188', 'https://www.amazon.de/dp/1037994', 'https://www.amazon.de/dp/000103863X', 'https://www.amazon.de/dp/1039466', 'https://www.ama
# ...

# %%
# importing libraries
name=[]
from bs4 import BeautifulSoup
import requests

def main(URL):
    # opening our output file in append mode
    File = open("out.csv", "a")

    # specifying user agent, You can use other user agents
    # available on the internet
    HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64)  AppleWebKit/537.36 (KHTML, like Gecko)  Chrome/44.0.2403.157 Safari/537.36',
                                'Accept-Language': 'en-US, en;q=0.5'})

    # Making the HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Creating the Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "lxml")

    # retrieving product title
    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id": 'productTitle'})

        # Inner NavigableString Object
       
        title_value = title.string
        # Title as a string value
        title_string = title_value.strip().replace(',', '')
        name.append(("Product Title  : = ",title_string))
        print("Product Title  := ",title_string)
       
    except AttributeError:
        pass
if __name__ == '__main__':
# opening our url file to access URLs
    file = b
    # iterating over the urls
    for links in file:
        main(links)
# Out:
# Product Title  :=  Fantasie c-Moll: BWV 9061. Klavier. (Edition Schott Einzelausgabe)
# Product Title  :=  Sonate op. 41 - Ausgabe für Fagott und Klavier (EB 5567)
# Product Title  :=  KANTATE 083 ERFREUTE ZEIT IM
# Product Title  :=  Arien(2) (grand macabre) 2e akte
# Product Title  :=  Moto perpetuo violon
# Product Title  :=  Ein deutsches requiem 2 klav
# Product Title  :=  Short story (dushkin/hegyi) violon: Violoncello und Klavier.
# Product Title  :=  Concertino bes violon
# Product Title  :=  Concert es kammerorchester parti musique d'ensemble
# Product Title  :=  Schulwerk vol. 1 (ted.) (orff/keetman)
# Product Title  :=  Funf antike oden op. 57 -ensemble de partitions: nach Gedichten von Sappho. op. 57. mittlere Frauenstimme Viola und Klavier. mittel. Stimmensatz.
# Product Title  :=  Complete songs with piano accompaniment band 2 chant
# Product Title  :=  Spielbuch orchestre: Sammlung wichtiger Passagen aus der Opern- und Konzertliteratur. Kontrabass.
# ...

# %%
name

# %%
from operator import imul
from PIL import Image
import requests
im = Image .open(requests.get("https://m.media-amazon.com/images/I/41xHbjdSXJL._SX425_PIbundle-2,TopRight,0,0_SX425SY266SH20_.jpg", stream=True).raw)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=425x266>

# %%
a = ['Choralfantasie feste burg orgue',
 'Concerto grosso 8 g opus 6 partitu',
 'Concertino bes violon',
 "Concert es kammerorchester parti musique d'ensemble",
 'Schulwerk vol. 1 (ted.) (orff/keetman)',
 'Funf antike oden op. 57 -ensemble de partitions: nach Gedichten von Sappho. op. 57. mittlere Frauenstimme Viola und Klavier. mittel. Stimmensatz.',
 'Etuden 1 & 2 orgue: Orgel.',
 'Complete songs with piano accompaniment band 2 chant',
 'Spielbuch orchestre: Sammlung wichtiger Passagen aus der Opern- und Konzertliteratur. Kontrabass.',
 'Wir horen und spielen band 3 piano: Ein Weg zum absoluten Gehör. Band 3. Klavier.',
 'Fantasie c piano',
 'Coucou piano',
 'Adelaide op.46',
 'Gnomenreigen piano',
 'Moto perpetuo violon: op. 11. Violine und Klavier.',
 'Happy birthday piano',
 'Duos(6) opus 1 flute traversiere',
 'Csardas-kompositionen clarinette',
 'Eingedunkelt: Neun Gedichte nach Paul Celan. Alt-Solo. Alt.',
 'Viola spaces vol. 1 alto: Contemporary Viola Studies. Band 1. Viola.',
 'Klaviertrio G-Dur Hob XV:15 (EB 1131)',
 'Violinkonzert 2 d-dur kv 211',
 '2 leichte Divertimenti für Violine (Oboe) Cello (Fagott) und Klavier - Es-dur KV 252 (240a) und B-dur KV 240 - Bearbeitung (EB 3810)',
 "Il Re pastore KV 208 - L'amerò sarò costante - Arie der Aminta - Ausgabe für Sorpan Violine und Klavier (EB 5473)",
 'Sonate op. 41 - Ausgabe für Fagott und Klavier (EB 5567)'
  "Fantasie über den Choral 'Ein feste Burg ist unser Gott' op. 27 für Orgel - Breitkopf Urtext (EB 8512)",
 '3 Stücke op. 142 für Orgel - 1. Stimmen der Nacht - 2. Violalse mignonne - 3. Romantisch (EB 8584)',
 'Ein deutsches requiem 2 klav',
 'Funf antike oden op. 57 -ensemble de partitions',
 'Viola spaces vol. 1 alto']
len(a)
# Out:
# 29
